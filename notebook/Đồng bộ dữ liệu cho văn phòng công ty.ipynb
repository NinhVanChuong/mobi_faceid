# %%
import pypi_xmlrpc #pip install pypi-xmlrpc
import csv
from tqdm import tqdm
import pandas as pd

# server = 'http://localhost:8069'
# database = "Diem_Danh_Hik_odoo17_9"
# user = "doanhdai1997@gmail.com"
# password = "Baodai123!"

server = 'https://faceid.mobifone5.vn'
database = "faceID"
user = "doanhdai1997@gmail.com"
password = "Baodai123!"

common = pypi_xmlrpc.ServerProxy('%s/xmlrpc/2/common' % server)
print(common.version())
odooApi = pypi_xmlrpc.ServerProxy('%s/xmlrpc/2/object' % server)
odooApi
uid = common.authenticate(database,user,password,{})
uid
# Out:
# {'server_version': '17.0-20241209', 'server_version_info': [17, 0, 0, 'final', 0, ''], 'server_serie': '17.0', 'protocol_version': 1}
# 2

# %% [markdown]
# # Đọc danh sách nhân viên

# %%
data = pd.read_excel('../Doc/ds_nv_full.xlsx',sheet_name='phong_cskh')
data
# Out:
#     STT  Mã nhân viên                Họ và tên  \
# 0   NaN            NaN         Phạm Thị Hà Ngân
# 1   NaN            NaN            Phạm Tuấn Anh
# 2   NaN            NaN          Trịnh Thái Hưng
# 3   NaN            NaN    Nguyễn Thị Hồng Thanh
# 4   NaN            NaN            Phạm Văn Hạnh
# 5   NaN            NaN        Nguyễn Duy Phương
# 6   NaN            NaN           Trần Tiến Dũng
# 7   NaN            NaN    Nguyễn Thị Thanh Thủy
# 8   NaN            NaN         Đào Thị Thúy Anh
# 9   NaN            NaN      Hoàng Thị Minh Hiền
# 10  NaN            NaN          Nguyễn Thị Hồng
# 11  NaN            NaN          Trần Thị Khuyến
# 12  NaN            NaN      Giang Thị Bích Huệ
# 13  NaN            NaN           Phạm Thị Hương
# 14  NaN            NaN  Nguyễn Thị Thanh Phương
# 15  NaN            NaN       Phạm Thị Ngọc Dung
# 16  NaN            NaN           Vũ Thị Tố Uyên
# 17  NaN            NaN         Nguyễn Thanh Huệ
# ...

# %%
# Trung tâm Kinh doanh công nghệ số : 5
data_sub = data[["Mã nhân viên","Họ và tên","Chức danh"]]
data_sub['department_id'] = 122
data_sub.rename(columns={'Mã nhân viên': 'emp_code_mobifone', 'Họ và tên': 'name','Chức danh':'job_title'}, inplace=True)
df_employee_dict = data_sub.to_dict('records')
create_result = odooApi.execute_kw(database,uid,password,'hr.employee','create',[df_employee_dict])
data_sub
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_19124\4143667838.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sub['department_id'] = 122
# C:\Users\admin\AppData\Local\Temp\ipykernel_19124\4143667838.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sub.rename(columns={'Mã nhân viên': 'emp_code_mobifone', 'Họ và tên': 'name','Chức danh':'job_title'}, inplace=True)
#     emp_code_mobifone                     name  \
# 0                 NaN         Phạm Thị Hà Ngân
# 1                 NaN            Phạm Tuấn Anh
# ...
